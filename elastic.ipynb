# %% [markdown]
# # 9-elasticsearch

# %%
import pandas as pd
import requests
import json

url = 'http://localhost:9200'
index = '/movies'

# %% [markdown]
# ### We have chosen IMDB dataset from kaggle
# https://www.kaggle.com/datasets/ashpalsingh1525/imdb-movies-dataset?resource=download

# %%
df = pd.read_csv('imdb_movies.csv').dropna().rename(columns={'names': 'name', 'budget_x': 'budget', 'date_x': 'date'})
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#                           name       date  score
# 0                    Creed III 2023-03-02   73.0  \
# 1     Avatar: The Way of Water 2022-12-15   78.0
# 2  The Super Mario Bros. Movie 2023-04-05   76.0
# 3                      Mummies 2023-01-05   70.0
# 4                    Supercell 2023-03-17   61.0
#
#                                            genre
# 0                                  Drama, Action  \
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview
# 0  After dominating the boxing world, Adonis Cree...  \
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
#                                                 crew
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...  \
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
#
#                     orig_title     status            orig_lang       budget
# 0                    Creed III   Released              English   75000000.0  \
# 1     Avatar: The Way of Water   Released              English  460000000.0
# 2  The Super Mario Bros. Movie   Released              English  100000000.0
# 3                       Momias   Released   Spanish, Castilian   12300000.0
# 4                    Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US

# %%
requests.get(url).json()
# Out:
# {'name': '851839bcfcfa',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'QOutGYOYQzGrXMGQnFU6SQ',
#  'version': {'number': '7.17.9',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': 'ef48222227ee6b9e70e502f0f0daa52435ee634d',
#   'build_date': '2023-01-31T05:34:43.305517834Z',
#   'build_snapshot': False,
#   'lucene_version': '8.11.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
requests.put(url+index).json()
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'movies'}

# %%
requests.get(url+'/_cat/indices').text.split('\n')
# Out:
# ['green  open .geoip_databases 9FMko0h1Sw6HdTamDGpbug 1 0 43 0 41mb 41mb',
#  'yellow open movies           ZhFuZdvhR96upLKj1I-8NQ 1 1  0 0 226b 226b',
#  '']

# %% [markdown]
# ## Create mapping
# we will import all the fields from the dataset.

# %%
mapping = {
    'properties': {
        'name': {
            'type': 'text'
        },
        'date': {
            'type': 'date'
        },
        'genre': {
            'type': 'text'
        },
        'overview': {
            'type': 'text'
        },
        'crew': {
            'type': 'text'
        },
        'orig_title': {
            'type': 'text'
        },
        'status': {
            'type': 'text'
        },
        'orig_lang': {
            'type': 'keyword'
        },
        'budget': {
            'type': 'long'
        },
        'revenue': {
            'type': 'double'
        },
        'country': {
            'type': 'keyword'
        }
    }
}

requests.put(url+index+'/_mapping', json=mapping).json()
# Out:
# {'acknowledged': True}

# %% [markdown]
# ## Bulk import to elk
# From the [documentation](https://www.elastic.co/guide/en/elasticsearch/reference/7.17/docs-bulk.html), we can see that we need to parse the json to ndjson and before each doc, we need to add what action should be execuded. We will index the following data.

# %%
data = []

for doc in df.to_dict('records'):
    data.append({'index': {'_index': index[1:], '_type':'_doc'}})
    doc['date'] = doc['date'].strftime('%Y-%m-%d')
    data.append(doc)

bulk_data = '\n'.join([json.dumps(doc) for doc in data]) + '\n'

requests.post(url+index+'/_bulk', data=bulk_data, headers={'Content-Type': 'application/x-ndjson'}).json()
# Out:
# {'took': 1016,
#  'errors': False,
#  'items': [{'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'coWkFogBRKR1tV-toFx3',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'c4WkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'dIWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'dYWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 3,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'doWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 4,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'd4WkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 5,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'eIWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 6,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'eYWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 7,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'eoWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 8,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'e4WkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 9,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'fIWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 10,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'fYWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 11,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'foWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 12,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'f4WkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 13,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'gIWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 14,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'gYWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 15,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'goWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 16,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'g4WkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 17,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'hIWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 18,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'hYWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 19,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'hoWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 20,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'h4WkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 21,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'iIWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 22,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'iYWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 23,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'ioWkFogBRKR1tV-toFx4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 24,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 

#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'MYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 959,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'MoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 960,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'M4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 961,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'NIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 962,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'NYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 963,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'NoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 964,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'N4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 965,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'OIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 966,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'OYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 967,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'OoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 968,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'O4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 969,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'PIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 970,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'PYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 971,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'PoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 972,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'P4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 973,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'QIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 974,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'QYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 975,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'QoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 976,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'Q4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 977,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'RIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 978,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'RYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 979,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'RoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 980,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'R4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 981,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'SIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 982,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'SYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 983,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'SoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 984,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'S4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 985,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'TIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 986,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'TYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 987,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'ToWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 988,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'T4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 989,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'UIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 990,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'UYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 991,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'UoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 992,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'U4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 993,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'VIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 994,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'VYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 995,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'VoWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 996,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'V4WkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 997,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'WIWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 998,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'movies',
#     '_type': '_doc',
#     '_id': 'WYWkFogBRKR1tV-toGB9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 999,
#     '_primary_term': 1,
#     'status': 201}},
#   ...]}

# %%
query = {
    'size': 100,
    'from': 0,
    'query': {
        'bool': {
            'must': {
                'match': {
                'crew': 'Chris Pratt'
                }
            }
        }
    },
}

results = requests.get(url+index+'/_search', json=query).json()

for hit in results['hits']['hits']:
    print(hit['_source']['name'], hit['_source']['date'], hit['_score'])
# Out:
# Marvel Studios Assembled: The Making of Thor: Love and Thunder 2022-09-08 9.92476
# Delivery Man 2014-12-18 8.985202
# Jurassic Greatest Moments: Jurassic Park to Jurassic World 2022-06-04 8.869982
# Thor: Love and Thunder 2022-07-06 8.767334
# Bride Wars 2009-01-09 8.75768
# Castle Freak 2020-12-04 8.75768
# Deep in the Valley 2009-09-30 8.437209
# The Guardians of the Galaxy Holiday Special 2022-11-25 8.236282
# Passengers 2016-12-29 8.236282
# Her 2014-01-16 8.139365
# Zero Dark Thirty 2013-01-31 8.139365
# Take Me Home Tonight 2011-03-04 8.139365
# Guardians of the Galaxy Vol. 2 2017-04-25 8.044703
# Moneyball 2011-09-23 8.044703
# The Tomorrow War 2021-07-02 7.952216
# Guardians of the Galaxy 2014-08-07 7.952216
# The Magnificent Seven 2016-09-29 7.952216
# Jennifer's Body 2010-03-31 7.952216
# The Five-Year Engagement 2012-05-03 7.952216
# Jurassic World 2015-06-11 7.8618326
# Guardians of the Galaxy Volume 3 2023-05-04 7.7734795
# Jurassic World: Fallen Kingdom 2018-06-21 7.7734795
# Jurassic World Dominion 2022-06-09 7.687092
# The Super Mario Bros. Movie 2023-04-05 7.519949
# The Lego Movie 2: The Second Part 2019-03-21 7.359921
# The Death of the Incredible Hulk 1990-02-18 7.282801
# Onward 2020-03-20 7.206562
# The Dressmaker 2015-10-29 7.166677
# The Lego Movie 2014-04-03 6.9182496
# Movie 43 2013-02-07 6.7825747
# Open Water 2: Adrift 2007-02-20 6.4224653
# Desperate Riders 2022-02-25 5.619484
# House of the Dead 2 2006-02-11 5.619484
# Wild Indian 2021-12-09 5.550093
# Under Wraps 2021-10-01 5.550093
# Hotel for Dogs 2009-06-18 5.550093
# About Fate 2022-09-09 5.482395
# Doctor Dolittle 1998-07-02 5.2888594
# Dr. Dolittle 2 2001-06-22 5.2888594
# Lolita 1997-09-27 5.2273493
# Lolita 1997-09-27 5.2273493
# 10 Things I Hate About You 1999-03-30 5.2273493
# Red Corner 1997-10-30 5.2273493
# Cruel Intentions 2 2001-03-13 5.2273493
# The Substitute 2: School's Out 1998-08-01 5.1672525
# Scarface 1932-04-09 5.1085224
# Enemy of the State 1999-01-07 5.1085224
# Overboard 1988-03-17 5.1085224
# Chris Rock: Selective Outrage 2023-03-04 4.5721245
# Just Friends 2006-02-09 4.489341
# Maggie Simpson in Playdate with Destiny 2020-03-06 4.4058137
# Play Dead 2023-01-05 4.233883
# Shark Beach With Chris Hemsworth 2021-07-09 4.107027
# 5 Headed Shark Attack 2017-07-30 4.0566306
# Melody Makers 2019-12-17 4.038557
# Shark Night 3D 2011-09-02 4.0229464
# My Teacher, My Obsession 2018-06-12 4.0229464
# Beverly Hills Ninja 1997-04-10 3.957229
# Demolition 2016-07-14 3.957229
# Come and Find Me 2016-11-11 3.957229
# Studio 666 2022-02-24 3.9251685
# The Aviary 2022-04-29 3.9082448
# Air 2023-04-05 3.8936238
# Rush Hour 1998-12-04 3.8936238
# Walking Tall 2004-04-02 3.8936238
# Willy's Wonderland 2021-04-08 3.8625817
# Tomorrow, When the War Began 2010-08-08 3.8625817
# American Sniper 2015-01-22 3.832031
# Live by Night 2017-01-26 3.832031
# American Pie 2 2001-12-06 3.8019593
# The Pursuit of Happyness 2007-01-11 3.8019593
# American Pie 1999-09-16 3.7723563
# Weaponized 2016-03-01 3.7723563
# The Red Sea Diving Resort 2019-07-28 3.7723563
# Cro Minion 2015-12-08 3.7278166
# The Maid 2014-04-12 3.7278166
# American Reunion 2012-04-04 3.7145116
# Creepshow 1983-03-31 3.6846352
# The Avengers 2012-04-25 3.6039865
# The Avengers 2012-04-25 3.6039865
# Big Brother 2018-08-16 3.6039865
# Exists 2014-03-17 3.5633125
# The Redeem Team 2022-10-07 3.551154
# The Mummy Resurrection 2023-01-02 3.511657
# Avengers: Endgame 2019-04-24 3.4998481
# Avengers: Age of Ultron 2015-04-23 3.4998481
# Umma 2022-05-20 3.4614782
# Avengers: Infinity War 2018-04-25 3.4500039
# The Monster 2016-11-11 3.3191924
# High Heat 2023-03-01 3.2306602
# 47 Meters Down 2019-10-31 3.2306602
# Avatar: The Deep Dive - A Special Edition of 20/20 2022-12-13 3.146728
# All About Sex 2020-01-16 3.146728
# Into the Blue 2005-10-20 3.146728
# Palm Springs 2020-11-20 3.146728
# Into the Blue 2: The Reef 2010-02-10 3.146728
# Black as Night 2021-10-01 3.146728
# Just Say Yes 2021-04-02 3.146728
# Tempus Tormentum 2018-04-17 3.146728
# Free Fire 2016-11-26 3.146728

# %%
query = {
    'size': 100,
    'from': 0,
    'sort': [
        {'date': {'order': 'desc'}},
        '_score',
    ],
    'query': {
        'match': {
        'crew': 'Chris Pratt'
        }
    },
}

results = requests.get(url+index+'/_search', json=query).json()

for hit in results['hits']['hits']:
    print(hit['_source']['name'], hit['_source']['date'], hit['_score'])
# Out:
# Extraction 2 2023-06-16 2.991301
# Renfield 2023-05-25 2.8505056
# Guardians of the Galaxy Volume 3 2023-05-04 7.7734795
# Ghosted 2023-04-20 3.0287
# The Super Mario Bros. Movie 2023-04-05 7.519949
# Air 2023-04-05 3.8936238
# Spinning Gold 2023-03-31 2.7849636
# Dungeons & Dragons: Honor Among Thieves 2023-03-30 2.7849636
# The Portable Door 2023-03-23 2.7849636
# Under Wraps 2021-10-01 5.550093
# Black as Night 2021-10-01 3.146728
# Demonic 2021-09-20 3.0287
# The Starling 2021-09-17 2.9548142
# The Lair of the White Worm 2021-08-20 2.8173535
# Endangered Species 2021-08-01 2.884447
# Shark Beach With Chris Hemsworth 2021-07-09 4.107027
# The Tomorrow War 2021-07-02 7.952216
# Ripper Untold 2021-06-28 3.1063764
# Justice Society: World War II 2021-06-01 2.4723105
# Vanquish 2021-05-31 2.9548142
# Blue Miracle 2021-05-27 3.0287
# Spiral: From the Book of Saw 2021-05-13 2.6921139
# Run Hide Fight 2021-05-01 2.8173535
# Four Good Days 2021-04-30 3.0287
# The Virtuoso 2021-04-30 2.8173535
# Willy's Wonderland 2021-04-08 3.8625817
# Sound of Metal 2021-04-08 3.0287
# Just Say Yes 2021-04-02 3.146728
# Bad Trip 2021-03-26 2.9192066
# Batman: Soul of the Dragon 2021-03-01 2.4723105
# Silk Road 2021-02-19 2.884447
# I Care a Lot 2021-02-19 2.8505056
# The Little Things 2021-02-18 2.6335785

# %% [markdown]
# ### We can add aggregation of Action genre match on language and country of origin.

# %%
query = {
    'size': 100,
    'from': 0,
    'query': {
        'match': {
        'genre': 'Action'
        }
    },
    'aggs': {
        'group_by_orig_lang': {
            'terms': {
                'field': 'orig_lang'
            }
        },
        'group_by_coutry': {
            'terms': {
                'field': 'country'
            }
        }
    }
}

results = requests.get(url+index+'/_search', json=query).json()

for hit in results['hits']['hits']:
    print(hit['_source']['name'], hit['_source']['date'], hit['_score'])
# Out:
# Supercell 2023-03-17 1.7533091
# Lord of the Streets 2022-04-22 1.7533091
# Overdose 2022-11-04 1.7533091
# The princess 2022-08-05 1.7533091
# Vendetta 2022-05-17 1.7533091
# One Shot 2022-01-01 1.7533091
# Crazy Fist 2021-05-06 1.7533091
# Narco Sub 2021-02-07 1.7533091
# The Vault 2021-07-06 1.7533091
# Redemption Day 2021-03-01 1.7533091
# Never Back Down: Revolt 2021-11-16 1.7533091
# Kate 2021-09-10 1.7533091
# Sniper: Ultimate Kill 2017-10-03 1.7533091
# The Protector 2 2013-10-23 1.7533091
# Outcast 2015-02-27 1.7533091
# Born to Race: Fast Track 2014-03-20 1.7533091
# Hard Target 1993-08-20 1.7533091
# The Debt Collector 2018-06-05 1.7533091
# Lionheart 1990-11-29 1.7533091
# The Marine 3: Homefront 2013-03-05 1.7533091
# Tracers 2015-09-02 1.7533091
# American Badger 2021-06-15 1.7533091
# Enter the Dragon 1973-11-01 1.7533091
# The Marine 2006-10-13 1.7533091
# Jesse Rodriguez vs. Cristian Gonzalez 2023-04-08 1.7533091
# Torque 2004-01-22 1.7533091
# Bastille Day 2016-05-12 1.7533091
# The Marine 5: Battleground 2017-03-29 1.7533091
# Fist of Legend 1994-12-22 1.7533091
# In the Name of Ben-Hur 2016-08-02 1.7533091
# Mercenaries 2014-08-05 1.7533091
# The Big Boss 1971-10-23 1.7533091
# Showdown in Little Tokyo 1992-07-23 1.7533091
# Shark: The Beginning 2021-06-17 1.7533091
# The Man with the Iron Fists 2 2015-03-10 1.7533091
# Garota da Moto 2021-09-23 1.7533091
# Army of One 2020-12-14 1.7533091
# Escape Plan: The Extractors 2019-07-02 1.7533091
# American Ninja 2: The Confrontation 1987-05-01 1.7533091
# The Hard Way 2019-03-05 1.7533091
# Primal 2019-11-08 1.7533091
# No Retreat, No Surrender 1986-05-02 1.7533091
# Hard to Kill 1990-05-17 1.7533091
# Coast Guard Malaysia: Ops Helang 2023-02-02 1.7533091
# The Condemned 2 2015-11-06 1.7533091
# Sniper: Assassin's End 2020-06-16 1.7533091
# Streets of Fire 1984-06-01 1.7533091
# Born to Race 2011-03-19 1.7533091
# The Man with the Iron Fists 2012-12-06 1.7533091
# TEKKEN: A Man Called X 2014-08-12 1.7533091
# Eliminators 2017-02-20 1.7533091
# Pound of Flesh 2015-05-07 1.7533091
# Sniper 2 2003-03-13 1.7533091
# Flight Crew 2016-04-21 1.7533091
# A Good Man 2014-08-19 1.7533091
# Miss Bala 2019-02-01 1.7533091
# Sudden Death 1996-01-11 1.7533091
# American Ninja 1986-07-03 1.7533091
# Joshua Tree 1994-10-18 1.7533091
# Revenger 2018-12-06 1.7533091
# Savage Dog 2017-08-04 1.7533091
# Flash Point 2007-08-09 1.7533091
# No Retreat, No Surrender 2: Raging Thunder 1989-01-27 1.7533091
# All the Devil's Men 2018-12-07 1.7533091
# Black Mask 1996-11-07 1.7533091
# Wake of Death 2004-12-28 1.7533091
# Crows Zero 2007-10-26 1.7533091
# Sky Hunter 2017-09-29 1.7533091
# Iron Eagle 1986-01-17 1.7533091
# Take Point 2018-12-26 1.7533091
# Riot 2015-09-27 1.7533091
# On Deadly Ground 1994-02-18 1.7533091
# The Marine 4: Moving Target 2015-04-10 1.7533091
# Nezha 2021-01-16 1.7533091
# Once Upon a Time in China III 1993-02-11 1.7533091
# The Marine 6: Close Quarters 2018-11-13 1.7533091
# Blown Away 1994-09-09 1.7533091
# American Heist 2015-07-14 1.7533091
# Fighting 2009-04-24 1.7533091
# The Wild Geese 1978-12-01 1.7533091
# The Marine 2 2009-12-29 1.7533091
# Sword Master 2016-12-02 1.7533091
# In Hell 2003-11-24 1.7533091
# Azumi 2: Death or Love 2005-03-12 1.7533091
# The Master 1992-05-28 1.7533091
# Delta Force 2: The Colombian Connection 1990-08-24 1.7533091
# Creed III 2023-03-02 1.4603169
# Sayen 2023-03-03 1.4603169
# Black Warrant 2023-03-01 1.4603169
# Top Gun: Maverick 2022-05-26 1.4603169
# Diabolik - Ginko Attacks 2022-11-17 1.4603169
# John Wick 2014-11-26 1.4603169
# Sisu 2023-01-27 1.4603169
# The Lair 2022-08-25 1.4603169
# Uncharted 2022-02-17 1.4603169
# Wolf Hound 2022-09-01 1.4603169
# RRR 2022-03-25 1.4603169
# Lesson Plan 2022-11-23 1.4603169
# Last Seen Alive 2022-05-19 1.4603169
# Lou 2022-09-23 1.4603169

# %%
results['aggregations']
# Out:
# {'group_by_coutry': {'doc_count_error_upper_bound': 0,
#   'sum_other_doc_count': 90,
#   'buckets': [{'key': 'AU', 'doc_count': 1588},
#    {'key': 'US', 'doc_count': 583},
#    {'key': 'JP', 'doc_count': 215},
#    {'key': 'KR', 'doc_count': 65},
#    {'key': 'HK', 'doc_count': 62},
#    {'key': 'CN', 'doc_count': 47},
#    {'key': 'FR', 'doc_count': 41},
#    {'key': 'GB', 'doc_count': 24},
#    {'key': 'IN', 'doc_count': 23},
#    {'key': 'RU', 'doc_count': 12}]},
#  'group_by_orig_lang': {'doc_count_error_upper_bound': 0,
#   'sum_other_doc_count': 74,
#   'buckets': [{'key': ' English', 'doc_count': 2025},
#    {'key': ' Japanese', 'doc_count': 294},
#    {'key': ' Korean', 'doc_count': 83},
#    {'key': ' Cantonese', 'doc_count': 82},
#    {'key': ' Chinese', 'doc_count': 81},
#    {'key': ' French', 'doc_count': 45},
#    {'key': ' Spanish, Castilian', 'doc_count': 20},
#    {'key': ' Russian', 'doc_count': 18},
#    {'key': ' Hindi', 'doc_count': 15},
#    {'key': ' Italian', 'doc_count': 13}]}}

# %% [markdown]
# ### **Japanese action!**

# %%
query = {
    'size': 100,
    'from': 0,
    'query': {
        'bool': {
            'must': [
                {'match': {'genre': 'Action'}},
                {'match': {'orig_lang': ' Japanese'}}
            ]
        }
    },
    'sort': [
        {'date': {'order': 'desc'}},
    ],
}

results = requests.get(url+index+'/_search', json=query).json()

for hit in results['hits']['hits']:
    print(hit['_source']['name'], hit['_source']['date'])
# Out:
# Black Clover: Sword of the Wizard King 2023-06-16
# Detective Conan: Black Iron Submarine 2023-04-14
# Princess Principal Crown Handler: Chapter 3 2023-04-07
# Sword Art Online the Movie -Progressive- Scherzo of Deep Night 2023-02-02
# Lupin The 3rd vs. Cat’s Eye 2023-01-27
# The Seven Deadly Sins: Grudge of Edinburgh Part 1 2022-12-20
# One Piece Film Red 2022-11-03
# Evangelion: 3.0+1.0 Thrice Upon a Time 2022-10-13
# Naruto 20th Anniversary - Road of Naruto 2022-10-02
# High & Low The Worst X 2022-09-09
# Dragon Ball Super: Super Hero 2022-08-18
# Fullmetal Alchemist: The Final Alchemy 2022-06-24
# Fullmetal Alchemist: The Revenge of Scar 2022-05-20
# Shin Ultraman 2022-05-13
# Jujutsu Kaisen 0 2022-03-17
# Sword Art Online the Movie -Progressive- Aria of a Starless Night 2021-12-09
# Lupin III: The First 2021-11-01
# My Hero Academia: World Heroes' Mission 2021-10-28
# Bright: Samurai Soul 2021-10-12
# Princess Principal Crown Handler: Chapter 2 2021-09-23
# Fate/kaleid liner Prisma☆Illya: Licht Nameless Girl 2021-08-27
# Fate/Grand Order the Movie: Divine Realm Of The Round Table: Camelot Paladin; Agateram 2021-08-26
# Fate/Grand Order Final Singularity – Grand Temple of Time: Solomon 2021-07-30
# Tokyo Revengers 2021-07-09
# Mobile Suit Gundam Hathaway 2021-06-11
# Rurouni Kenshin: The Beginning 2021-06-04
# Detective Conan: The Scarlet Bullet 2021-05-13
# Rurouni Kenshin: The Final 2021-04-23
# Fate/Grand Order the Movie: Divine Realm of the Round Table: Camelot Wandering; Agateram 2021-04-08
# Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train 2021-02-25
# Pretty Guardian Sailor Moon Eternal The Movie Part 2 2021-02-11
# Princess Principal Crown Handler: Chapter 1 2021-02-11
# Grisaia: Phantom Trigger The Animation - Stargazer 2020-11-27
# Fate/stay night: Heaven's Feel III. Spring Song 2020-11-19
# Psycho-Pass 3: First Inspector 2020-03-27
# My Hero Academia: Heroes Rising 2020-03-12
